# %%
##### Purpose:  featurize the sentences, and make a naive bayes classifier
##### Author: Julia Cope
##### Creation Date: 05/03/23
##### Project: A2 NLP - capturing climate claims 
##### Inputs: 
##### Inputs: 
##### Inputs: 11_climate_dataset.csv
##### Output: 
##### Output: 
##### Output:

# %%
### libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords
from gensim.models import LdaModel
from gensim.corpora import Dictionary

from gensim.models.coherencemodel import CoherenceModel
from sklearn.model_selection import train_test_split

# %%
climate_df = pd.read_csv('03_Outputs/11_climate_dataset.csv',parse_dates=['Date'])

# %%
climate_df['sentences'] = climate_df['sentences'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8').str.lower()

# %%
climate_df['sentences'] = climate_df['sentences'].str.replace('carbon capture', 'carbon_capture')
climate_df['sentences'] = climate_df['sentences'].str.replace('climate change', 'climate_change')
climate_df['sentences'] = climate_df['sentences'].str.replace('global warming', 'global_warming')
climate_df['sentences'] = climate_df['sentences'].str.replace('crude oil', 'crude_oil')
climate_df['sentences'] = climate_df['sentences'].str.replace('energy efficiency', 'energy_efficiency')
climate_df['sentences'] = climate_df['sentences'].str.replace('natural gas', 'natural_gas')
climate_df['sentences'] = climate_df['sentences'].str.replace('renewable energy', 'renewable_energy')

# %%
climate_df
# Out:
#        Unnamed: 0  index       Date  company  \
# 0               1   1655 2002-12-17    Exxon
# 1               2    401 2003-02-03  Chevron
# 2               3    133 2003-05-14  Chevron
# 3               4   1875 2003-10-01    Exxon
# 4               5   1860 2004-04-27  Chevron
# ...           ...    ...        ...      ...
# 63610       63611   8665 2012-07-31  Chevron
# 63611       63612   3794 2020-12-04   Valero
# 63612       63613  17354 2020-02-13  Chevron
# 63613       63614   5501 2005-02-18  Chevron
# 63614       63615  12753 2014-08-27    Exxon
#
#                                                sentences  Year  X1
# 0      factors that could cause actual results to dif...  2002   1
# 1      "while offering no guarantees that they'll be ...  2003   1
# 2      and it's significant that this year's event ta...  2003   1
# 3      importance will be attached to secure a balanc...  2003   1
# 4      the u.s. department of energy (doe) today anno...  2004   1
# ...                                                  ...   ...  ..
# 63610  karen hinton, the spokesperson for the ecuador...  2012   1
# 63611  a few notable trends may include increasing rd...  2020   1
# 63612  in fact, as much as the price erosion in crude...  2020   1
# 63613  future full-scale hydrogen energy stations cou...  2005   1
# 63614  the leaders and voices converged last week at ...  2014   1
#
# [63615 rows x 7 columns]

# %%
## strip_accents = 'unicode', stop_words='english')

# %%
# Preprocess text data
data_processed = [simple_preprocess(remove_stopwords(sent)) for sent in climate_df['sentences']]

# %%
#data_processed

# %%
# Create dictionary and corpus
dictionary = Dictionary(data_processed)
corpus = [dictionary.doc2bow(text) for text in data_processed]

# %%
# Define model parameters
num_topics = 9

# %%
# Instantiate LDA model
### maybe change it so the dictionary has fewer words...?
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, random_state=1)

# %%
# Extract output
topic_words = lda_model.print_topics()

# %%
topic_words
# Out:
# [(0,
#   '0.062*"energy" + 0.032*"power" + 0.021*"inc" + 0.017*"fuels" + 0.016*"products" + 0.016*"company" + 0.015*"corporation" + 0.014*"chevron" + 0.013*"solutions" + 0.012*"natural_gas"'),
#  (1,
#   '0.030*"energy" + 0.026*"fuel" + 0.015*"technology" + 0.011*"hydrogen" + 0.010*"carbon" + 0.010*"emissions" + 0.009*"new" + 0.009*"technologies" + 0.009*"low" + 0.008*"world"'),
#  (2,
#   '0.019*"environmental" + 0.015*"chevron" + 0.015*"oil" + 0.014*"company" + 0.012*"climate" + 0.011*"climate_change" + 0.010*"companies" + 0.008*"exxonmobil" + 0.008*"exxon" + 0.008*"today"'),
#  (3,
#   '0.017*"including" + 0.013*"factors" + 0.013*"environmental" + 0.012*"changes" + 0.011*"ability" + 0.011*"risks" + 0.009*"business" + 0.009*"conditions" + 0.009*"results" + 0.009*"capital"'),
#  (4,
#   '0.042*"ii" + 0.032*"emissions" + 0.020*"gas" + 0.019*"table" + 0.014*"oil" + 0.014*"carbon" + 0.014*"greenhouse" + 0.012*"includes" + 0.012*"oils" + 0.010*"iii"'),
#  (5,
#   '0.060*"market" + 0.016*"global" + 0.016*"demand" + 0.016*"growth" + 0.011*"industry" + 0.011*"report" + 0.010*"analysis" + 0.010*"key" + 0.009*"oil" + 0.008*"fuel"'),
#  (6,
#   '0.024*"environmental" + 0.015*"carbon" + 0.012*"business" + 0.012*"safety" + 0.012*"environment" + 0.011*"sustainability" + 0.009*"renewable" + 0.009*"health" + 0.009*"lower" + 0.008*"said"'),
#  (7,
#   '0.023*"energy" + 0.018*"million" + 0.011*"year" + 0.010*"diesel" + 0.009*"renewable" + 0.008*"capacity" + 0.008*"environmental" + 0.007*"production" + 0.007*"president" + 0.006*"approximately"'),
#  (8,
#   '0.027*"company" + 0.021*"potential" + 0.019*"future" + 0.015*"crude_oil" + 0.013*"development" + 0.012*"operations" + 0.012*"factors" + 0.011*"actions" + 0.010*"existing" + 0.010*"litigation"')]

# %%
# save the top topic number to each row in the corpus DataFrame
for i, doc in enumerate(corpus):
    doc_topics = lda_model.get_document_topics(doc)
    top_topic = max(doc_topics, key=lambda x: x[1])[0]
    climate_df.at[i, 'topic'] = top_topic

# %%
climate_df
# Out:
#        Unnamed: 0  index       Date  company  \
# 0               1   1655 2002-12-17    Exxon
# 1               2    401 2003-02-03  Chevron
# 2               3    133 2003-05-14  Chevron
# 3               4   1875 2003-10-01    Exxon
# 4               5   1860 2004-04-27  Chevron
# ...           ...    ...        ...      ...
# 63610       63611   8665 2012-07-31  Chevron
# 63611       63612   3794 2020-12-04   Valero
# 63612       63613  17354 2020-02-13  Chevron
# 63613       63614   5501 2005-02-18  Chevron
# 63614       63615  12753 2014-08-27    Exxon
#
#                                                sentences  Year  X1  topic
# 0      factors that could cause actual results to dif...  2002   1    3.0
# 1      "while offering no guarantees that they'll be ...  2003   1    1.0
# 2      and it's significant that this year's event ta...  2003   1    1.0
# 3      importance will be attached to secure a balanc...  2003   1    6.0
# 4      the u.s. department of energy (doe) today anno...  2004   1    1.0
# ...                                                  ...   ...  ..    ...
# 63610  karen hinton, the spokesperson for the ecuador...  2012   1    2.0
# 63611  a few notable trends may include increasing rd...  2020   1    5.0
# 63612  in fact, as much as the price erosion in crude...  2020   1    4.0
# 63613  future full-scale hydrogen energy stations cou...  2005   1    1.0
# 63614  the leaders and voices converged last week at ...  2014   1    7.0
#
# [63615 rows x 8 columns]

# %%
### select 5 sentences per year 

#random.seed(42)
train, test = train_test_split(climate_df, train_size=440, stratify=climate_df[['topic','Year']], random_state=7)



# Print the shape of the training and testing sets
print('Training set shape:', train.shape)
print('Testing set shape:', test.shape)
# Out:
# Training set shape: (440, 8)
# Testing set shape: (63175, 8)

# %%
#print(dictionary.id2token)
# Out:
# {0: 'accelerating', 1: 'acquiring', 2: 'actual', 3: 'agencies', 4: 'business', 5: 'businesses', 6: 'cause', 7: 'commission', 8: 'common', 9: 'company', 10: 'complementary', 11: 'concentration', 12: 'conditions', 13: 'consolidating', 14: 'covenants', 15: 'credit', 16: 'customer', 17: 'debt', 18: 'detailed', 19: 'differ', 20: 'difficulties', 21: 'economic', 22: 'environmental', 23: 'exchange', 24: 'existing', 25: 'expectations', 26: 'extensive', 27: 'facilities', 28: 'factors', 29: 'federal', 30: 'filings', 31: 'fluctuations', 32: 'general', 33: 'growth', 34: 'identifying', 35: 'include', 36: 'internal', 37: 'issues', 38: 'limited', 39: 'markets', 40: 'metals', 41: 'operating', 42: 'operations', 43: 'prices', 44: 'refinancing', 45: 'regulation', 46: 'related', 47: 'restrictive', 48: 'results', 49: 'risk', 50: 'risks', 51: 'sales', 52: 'securities', 53: 'short', 54: 'state', 55: 'stock', 56: 'subsidiaries', 57: 'term', 58: 'to', 59: 'uncertainties', 60: 'workplace', 61: 'air', 62: 'availability', 63: 'clean', 64: 'directly', 65: 'fleet', 66: 'future', 67: 'guarantees', 68: 'll', 69: 'means', 70: 'offering', 71: 'provide', 72: 'selected', 73: 'signaling', 74: 'survey', 75: 'technology', 76: 'testing', 77: 'they', 78: 'while', 79: 'areas', 80: 'cell', 81: 'emission', 82: 'event', 83: 'fuel', 84: 'impact', 85: 'improve', 86: 'it', 87: 'month', 88: 'place', 89: 'positive', 90: 'quality', 91: 'reinforcing', 92: 'significant', 93: 'struggling', 94: 'takes', 95: 'vehicles', 96: 'year', 97: 'zero', 98: 'activities', 99: 'attached', 100: 'balance', 101: 'connected', 102: 'development', 103: 'environment', 104: 'farming', 105: 'fish', 106: 'fisheries', 107: 'importance', 108: 'industry', 109: 'interests', 110: 'petroleum', 111: 'secure', 112: 'sustainable', 113: 'announced', 114: 'application', 115: 'cells', 116: 'chevrontexaco', 117: 'co', 118: 'consisting', 119: 'corp', 120: 'demonstration', 121: 'department', 122: 'designed', 123: 'doe', 124: 'energy', 125: 'five', 126: 'hydrogen', 127: 'hyundai', 128: 'lead', 129: 'motor', 130: 'practical', 131: 'project', 132: 'showcase', 133: 'team', 134: 'today', 135: 'utc', 136: 'validation', 137: 'gets', 138: 'item', 139: 'particular', 140: 'platform', 141: 'power', 142: 'says', 143: 'sun', 144: 'unbylined', 145: 'wind', 146: 'burnable', 147: 'create', 148: 'industrial', 149: 'oil', 150: 'process', 151: 'relatively', 152: 'sophisticated', 153: 'area', 154: 'city', 155: 'classes', 156: 'dallas', 157: 'educational', 158: 'enrichment', 159: 'exxonmobil', 160: 'green', 161: 'high', 162: 'jobs', 163: 'managed', 164: 'paid', 165: 'provides', 166: 'school', 167: 'sponsored', 168: 'students', 169: 'summer', 170: 'alj', 171: 'alon', 172: 'association', 173: 'better', 174: 'communications', 175: 'corporation', 176: 'ethanol', 177: 'exxon', 178: 'frontier', 179: 'fto', 180: 'fuels', 181: 'gathered', 182: 'gpre', 183: 'inc', 184: 'investment', 185: 'july', 186: 'mobil', 187: 'nasdaq', 188: 'new', 189: 'ny', 190: 'nyse', 191: 'october', 192: 'plains', 193: 'presswire', 194: 'production', 195: 'released', 196: 'renewable', 197: 'statistics', 198: 'stockprofiler', 199: 'sunoco', 200: 'us', 201: 'usa', 202: 'valero', 203: 'vlo', 204: 'xom', 205: 'york', 206: 'capabilities', 207: 'connect', 208: 'dr', 209: 'fit', 210: 'jacobs', 211: 'leadership', 212: 'partners', 213: 'reforming', 214: 'research', 215: 'said', 216: 'scale', 217: 'steam', 218: 'technical', 219: 'traditional', 220: 'vehicle', 221: 'way', 222: 'with', 223: 'advance', 224: 'agreement', 225: 'algae', 226: 'cfa', 227: 'chevron', 228: 'collaborative', 229: 'com', 230: 'cvx', 231: 'entered', 232: 'http', 233: 'laboratory', 234: 'liquid', 235: 'national', 236: 'nrel', 237: 'produce', 238: 'report', 239: 'stocksjournal', 240: 'study', 241: 'transportation', 242: 'visit', 243: 'wednesday', 244: 'www', 245: 'adopted', 246: 'carbon', 247: 'electricity', 248: 'emissions', 249: 'government', 250: 'hawaii', 251: 'mandates', 252: 'reduce', 253: 'solar', 254: 'sour ...

# %%
climate_df.to_csv('03_Outputs/12_topics_climate_df.csv', index=False)

# %%
train.to_csv('03_Outputs/12_sample_topic_sents.csv', index=False)
# Out:
#        Unnamed: 0  index       Date   company  \
# 47170       47171  26289 2020-01-22     Exxon
# 28136       28137  13078 2011-12-08     Exxon
# 38870       38871   1610 2020-03-04  Marathon
# 4890         4891   8256 2013-03-20     Exxon
# 45140       45141  16507 2021-12-15   Chevron
# ...           ...    ...        ...       ...
# 30935       30936  22249 2016-10-17     Exxon
# 52322       52323  16529 2022-03-11   Chevron
# 57925       57926  16481 2021-10-01   Chevron
# 31433       31434   8739 2011-11-14     Exxon
# 23379       23380  16986 2022-11-15   Chevron
#
#                                                sentences  Year  X1  topic
# 47170  generation revenues increased 96% to $14.0 mil...  2020   1    7.0
# 28136  according to a team of german scientists the c...  2011   1    2.0
# 38870  factors that could cause our actual results to...  2020   1    3.0
# 4890   over the past decade, the site has invested ov...  2013   1    4.0
# 45140  if established, additional details about the h...  2021   1    1.0
# ...                                                  ...   ...  ..    ...
# 30935  as part of this partnership, last month we ann...  2016   1    1.0
# 52322  in contrast, current technologies in use for c...  2022   1    1.0
# 57925  san ramon, calif- chevron corporation (nyse: c...  2021   1    2.0
# 31433  accrued environmental reserves at the end of t...  2011   1    7.0
# 23379  ahead of this, ice is bringing together a pane...  2022   1    6.0
#
# [440 rows x 8 columns]
